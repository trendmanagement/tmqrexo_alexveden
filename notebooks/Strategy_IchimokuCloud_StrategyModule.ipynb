# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys,os
sys.path.append('..')
from backtester import matlab, backtester
from backtester.analysis import *
from backtester.strategy import StrategyBase, OptParam, OptParamArray
from backtester.swarms.manager import SwarmManager
from backtester.swarms.ranking import SwarmRanker
from backtester.swarms.rebalancing import SwarmRebalance
from backtester.swarms.filters import SwarmFilter
from backtester.costs import CostsManagerEXOFixed
from backtester.exoinfo import EXOInfo

from backtester.positionsizing import PositionSizingBase
import pandas as pd
import numpy as np
import scipy

# %%
from strategies.strategy_ichimokucloud import StrategyIchimokuCloud

# %% [markdown]
# ## Script settings

# %%
STRATEGY_CONTEXT = {
    'strategy': { 
        'class': StrategyIchimokuCloud,
        'exo_name': 'strategy_270225',        
        'opt_params': [
                        #OptParam(name, default_value, min_value, max_value, step)
                        OptParamArray('Direction', [-1]),
                        OptParamArray('conversion_line_period', [9, 9*2, 9/2]),
                        OptParamArray('base_line_period', [26, 26*2, 26/2]),
                        OptParamArray('leading_spans_lookahead_period', [26, 26*2, 26/2]),
                        OptParamArray('leading_span_b_period', [52, 52*2, 52/2]),
                        OptParamArray('RulesIndex', np.arange(17)),
                        OptParam('MedianPeriod', 5, 1, 5, 1)
            ],
    },
    'swarm': {
        'members_count': 5,
        'ranking_function': SwarmRanker.highestreturns_universal,
        'ranking_params': {
            # 'ranking_type' - global ranking mode
            # 'returns' - main ranking function based on highest returns N days
            # 'relstr_ratio' - relative strength (equity / MA(equity)) (has negative equity BUG!)
            # 'relstr_delta' - relative strength (equity - MA(equity))            
            'ranking_type': 'relstr_delta',
            
            # Used for 'ranking_type' = 'relstr'
            'ranking_relstr_ma_period': 21,
            'ranking_relstr_upperbound': 1.5,
            'ranking_relstr_lowerbound': 0.01,
            
            # Used for 'ranking_type' = 'returns'
            # Ranking function exta parameters (main ranking metric period)
            'ranking_returns_period': 4,
            
            # Ignoring all members which equity less than it's MovingAverage({ignore_eqty_less_ma_period})
            #'ignore_eqty_less_ma': True,                    # Comment the line to turn off
            'ignore_eqty_less_ma_period': 90,               # Equity Moving Average period
            
            # Ignoring all members which equity less than TOP swarmmembers quantile
            #'ignore_eqty_less_top_quantile': True,          # Comment the line to turn off
            'ignore_eqty_less_top_quantile_threshold': 0.5,  # Ignore all members less than 0.9 quantile
            
            # Ignoring all swarm members wich have negative MA slope 
            #'ignore_eqty_with_negative_ma_slope': True,     # Comment the line to turn off
            'ignore_eqty_with_negative_ma_period': 90,      # Period of moving average
            'ignore_eqty_with_negative_ma_slope_period': 5, # Slope lookback filter = MA-MA[-slope_lookback] <= 0
            
            # Ignoring all swarm members when the change of AvgSwarm equity is negative
            #'ignore_if_avg_swarm_negative_change': True,      # Comment the line to turn off
            'ignore_if_avg_swarm_negative_change_period': 14, # AvgSwarm change period 
            
        },
        'rebalance_time_function': SwarmRebalance.every_monday,    
        # SwarmFilter.swingpoint_daily - original TMQR Swingpoint logics from Matlab
        # SwarmFilter.volatility_chandelier - Alex's volatility based logic (old name: SwarmFilter.swingpoint_threshold)
        'global_filter_function': SwarmFilter.volatility_chandelier,
        'global_filter_params': {
            'up_factor': 5.0,
            'down_factor': 15.0,
            'period': 5,
        },      
    },
    'costs':{
        'manager': CostsManagerEXOFixed,
        'context': {
            'costs_options': 3.0,
            'costs_futures': 3.0,
        }
    }
}

# %% [markdown]
# # Backtest class based strategy

# %% [markdown]
# ### WARNING! Do not run next block if you want to load swarm from file!

# %%
smgr = SwarmManager(STRATEGY_CONTEXT)
smgr.run_swarm()
smgr.pick()

# Saving results to swarms directory
smgr.save('./swarms/')

# %% [markdown]
# ### WARNING! Loading swarm from file (don't run next cell if you want new swarm instance)

# %%
#smgr = SwarmManager.load(strategy_context=STRATEGY_CONTEXT, directory='./swarms/')
#print('Loading: '+smgr.get_swarm_name())

# %%
figsize(10,10)
smgr.swarm_picked.sum(axis=1).plot(label='Picked swarm equity');
smgr.swarm_avg.plot(label='Average swarm equity');
legend(loc=2);

# %%
smgr.swarm.plot(legend=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-631cd44ef892> in <module>()
# ----> 1 smgr.swarm.plot(legend=False)
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\tools\plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3735                           fontsize=fontsize, colormap=colormap, table=table,
#    3736                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3737                           sort_columns=sort_columns, **kwds)
#    3738     __call__.__doc__ = plot_frame.__doc__
#    3739
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\tools\plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2609                  yerr=yerr, xerr=xerr,
#    2610                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2611                  **kwds)
#    2612
#    2613
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\tools\plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2436         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2437
# -> 2438     plot_obj.generate()
#    2439     plot_obj.draw()
#    2440     return plot_obj.result
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\tools\plotting.py in generate(self)
#    1023         self._compute_plot_data()
#    1024         self._setup_subplots()
# -> 1025         self._make_plot()
#    1026         self._add_table()
#    1027         self._make_legend()
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\tools\plotting.py in _make_plot(self)
#    1702                              stacking_id=stacking_id,
#    1703                              is_errorbar=is_errorbar,
# -> 1704                              **kwds)
#    1705             self._add_legend_handle(newlines[0], label, index=i)
#    1706
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\tools\plotting.py in _ts_plot(cls, ax, x, data, style, **kwds)
#    1740         ax._plot_data.append((data, cls._kind, kwds))
#    1741
# -> 1742         lines = cls._plot(ax, data.index, data.values, style=style, **kwds)
#    1743         # set date formatter, locators and rescale limits
#    1744         format_dateaxis(ax, ax.freq)
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\tools\plotting.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1717             cls._initialize_stacker(ax, stacking_id, len(y))
#    1718         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds['label'])
# -> 1719         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1720         cls._update_stacker(ax, stacking_id, y)
#    1721         return lines
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\tools\plotting.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#    1326
#    1327         if isinstance(x, Index):
# -> 1328             x = x._mpl_repr()
#    1329
#    1330         if is_errorbar:
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\tseries\period.py in _mpl_repr(self)
#     515     def _mpl_repr(self):
#     516         # how to represent ourselves to matplotlib
# --> 517         return self._get_object_array()
#     518
#     519     def equals(self, other):
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\tseries\period.py in _get_object_array(self)
#     511         freq = self.freq
#     512         return np.array([Period._from_ordinal(ordinal=x, freq=freq)
# --> 513                          for x in self.values], copy=False)
#     514
#     515     def _mpl_repr(self):
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\tseries\period.py in <listcomp>(.0)
#     511         freq = self.freq
#     512         return np.array([Period._from_ordinal(ordinal=x, freq=freq)
# --> 513                          for x in self.values], copy=False)
#     514
#     515     def _mpl_repr(self):
#
# pandas\src\period.pyx in pandas._period.Period._from_ordinal (pandas\src\period.c:10566)()
#
# pandas\src\period.pyx in pandas._period.Period._maybe_convert_freq (pandas\src\period.c:10248)()
#
# C:\Users\user\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# C:\Users\user\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# C:\Users\user\Anaconda3\lib\importlib\_bootstrap.py in _find_spec(name, path, target)
#
# C:\Users\user\Anaconda3\lib\importlib\_bootstrap_external.py in find_spec(cls, fullname, path, target)
#
# C:\Users\user\Anaconda3\lib\importlib\_bootstrap_external.py in _get_spec(cls, fullname, path, target)
#
# C:\Users\user\Anaconda3\lib\importlib\_bootstrap_external.py in find_spec(self, fullname, target)
#
# C:\Users\user\Anaconda3\lib\importlib\_bootstrap_external.py in _path_stat(path)
#
# KeyboardInterrupt:

# %%
figsize(10,10)
smgr.swarm_picked.sum(axis=1).plot(label='Picked swarm equity');
smgr.swarm_avg.plot(label='Average swarm equity');
legend(loc=2);

# %%
smgr.swarm_picked_inposition.sum(axis=1).plot()

# %% [markdown]
# # Swarm statistics

# %% [markdown]
# #### Non-picked swarm stats

# %%
smgr.get_swarm_stats(smgr.swarm_stats)
# Out:
# {'AvgTradesPerSwarmMember': 72.86154970760234,
#  'AvgWinRatePerSwarmMember': 0.5568999966683759,
#  'CommissionSum': -11978376.0,
#  'NetProfit': 95931250.49999999,
#  'SwarmMembersCount': 6840,
#  'TradesCount': 498373.0}

# %% [markdown]
# #### Picked swarm stats

# %%
smgr.get_swarm_stats(smgr.swarm_picked_stats)
# Out:
# {'AvgTradesPerSwarmMember': 1.6207407407407408,
#  'AvgWinRatePerSwarmMember': 0.5050872748650526,
#  'CommissionSum': -26256.0,
#  'NetProfit': 114643.99999999939,
#  'SwarmMembersCount': 675,
#  'TradesCount': 1094.0}

# %% [markdown]
# ## Exo information

# %%
smgr.strategy.exoinfo.exo_info
# Out:
# {'legs': 4,
#  'margin': 3850,
#  'name': 'BearishCollarBrokenWing',
#  'pcf': array([1, 2, 0, 1], dtype=uint8),
#  'pcfqty': array([-1, -1,  1,  1], dtype=int16),
#  'tickincrement': 0.25,
#  'tickvalue': 12.5,
#  'underlying': 'EP'}

# %%
smgr.strategy.exoinfo.data.exo.plot()

# %% [markdown]
# ### Global filter information

# %%
title(smgr.strategy.global_filter_data['name'])
smgr.swarm_picked.sum(axis=1).plot(label='Picked swarm equity with filter')
smgr.strategy.global_filter_data['input_equity'].plot(label='Picked swarm equity without filter (input)')
smgr.strategy.global_filter_data['values'].plot(label='Global filter')

legend(loc=2);

# %%
smgr.strategy.global_filter.plot.area()

# %% [markdown]
# ## Costs information (per 1-exo unit)

# %%
figsize(10,5)
smgr.strategy.costs.plot()

# %% [markdown]
# ## Margin graphs

# %% [markdown]
# ### EXO Margin (per 1 EXO unit)

# %%
smgr.strategy.exoinfo.margin().plot()

# %% [markdown]
# ### Average swarm margin

# %%
(smgr.swarm_picked_margin).rolling(30).mean().plot()

# %% [markdown]
# # Saving results

# %%
smgr.save('./swarms/'+smgr.get_swarm_name()+'.swm')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-20-d695305ca2f2> in <module>()
# ----> 1 smgr.save('./swarms/'+smgr.get_swarm_name()+'.swm')
#
# C:\Users\user\Dropbox\tmqrexo\tmqrv\backtester\swarms\manager.py in save(self, directory, filename)
#     197     def save(self, directory,  filename=None):
#     198         if not os.path.isdir(directory):
# --> 199             os.makedirs(directory)
#     200
#     201         if filename is None:
#
# C:\Users\user\Anaconda3\lib\os.py in makedirs(name, mode, exist_ok)
#     239             return
#     240     try:
# --> 241         mkdir(name, mode)
#     242     except OSError:
#     243         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [WinError 183] Невозможно создать файл, так как он уже существует: './swarms/EP_BearishCollarBrokenWing_IchimokuCloud_Short.swm'
