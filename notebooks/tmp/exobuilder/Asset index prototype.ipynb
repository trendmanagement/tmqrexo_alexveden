# %%
import pymongo
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/')
db = client['tmldb']

# %%
from datetime import datetime

# %%
collection = db['instruments']

# %%
from bson.son import SON
fut_chains = collection.aggregate(
[
   {
      '$lookup':
        {
          "from": "contracts",
          "localField": 'idinstrument',
          "foreignField": 'idinstrument',
          "as": "futures_chains"
        },
   },
   {   
       "$sort": SON([("futures_chains.expirationdate", -1)])
   }
   
   
])

# %%
db.options.create_index([('idcontract', pymongo.ASCENDING),('expirationdate', pymongo.ASCENDING), ('strike', pymongo.ASCENDING),  ])
# Out:
# 'idcontract_1_expirationdate_1_strike_1'

# %%
import time
start = time.time()

def get_opt_chain(idcontract):
    c = db.options.aggregate([
    {'$match': { 'idcontract' : idcontract }},     
    {'$sort': SON([('expirationdate', 1), ('strikeprice', 1)])},
    {'$group': { "_id" : "$expirationdate",
                "strikes": { "$addToSet": "$strikeprice" }}},

    ])

    expirations_values = []
    for item in c:
        c2 = db.options.aggregate([
            {'$match': { 'idcontract' : idcontract }},     
            {'$match': { 'expirationdate' : item['_id'] }},
            {'$match': { 'strikeprice' : {"$in": item['strikes']} }},     
            {'$group': { "_id" : "$strikeprice",
                        'chain': { "$push": "$$ROOT" }}},
            {'$sort': SON([('_id', 1)])},   ])

        strikes_values = []
        for s in c2:
            #print(s)
            strikes_values.append(s)
            #pprint.pprint(s)
        item['strikes'] = strikes_values

        #pprint.pprint(item)
        expirations_values.append(item)
    
    return expirations_values

import pprint
for instrument in  collection.find():
    fut_chains = []
    for contract in db.contracts.find({'idinstrument': instrument['idinstrument']}).sort('expirationdate'):
        option_chains = []
        
        contract['option_chains'] = get_opt_chain(contract['idcontract'])        
        #pprint.pprint(contract)
        fut_chains.append(contract)
        
    instrument['fut_chains'] = fut_chains
    
    #pprint.pprint(instrument)
    #instrument['_id'] = instrument['cqgsymbol']
    del instrument['_id']
    db.assetindex.insert_one(instrument)
    

    
    
end = time.time()
print(end - start)
# Out:
# 31.704676151275635

# %%
for option in db.options.find({'idcontract': 7079}).sort([('expirationdate', 1)]):
    print(option)

# %%
db.options.create_index([('exchangesymbol', pymongo.ASCENDING)])
# Out:
# 'exchangesymbol_1'

# %%
sym = db.instruments.find({'exchangesymbol':'CL'}).next()

# %%
db.futures_data.find({'exchangesymbol':'CL'}).next()
# Out:
# {'_id': ObjectId('577a4f7c4b01f47f84ca9ca4'),
#  'admcode': 'CU',
#  'admexchangecode': '07',
#  'admfuturepricefactor': 1.0,
#  'admoptionftpfilestrikedisplay': 50.0,
#  'admoptionpricefactor': 1.0,
#  'commissionpercontract': 2.99,
#  'cqgsymbol': 'CLE',
#  'customdayboundarytime': datetime.datetime(1900, 1, 1, 11, 15),
#  'datastart': datetime.datetime(2009, 1, 1, 0, 0),
#  'decisionoffsetminutes': 5,
#  'description': 'Crude Oil',
#  'enabled': 1,
#  'exchangesymbol': 'CL',
#  'exchangesymbolTT': 'CL',
#  'idAssetClass': 3,
#  'idexchange': 3,
#  'idinstrument': 21,
#  'idinstrumentgroup': 4,
#  'instrumentid_eod': 0,
#  'instrumentsymbol_pre_eod': '',
#  'instrumentsymboleod_eod': '',
#  'limittickoffset': 10,
#  'listedspread': 0,
#  'margin': 4510,
#  'modeled': 1,
#  'notes': '',
#  'optionadmstrikedisplay': 50.0,
#  'optiondatamonthscollected': 12,
#  'optionenabled': 2,
#  'optionexchangesymbol': 'LO',
#  'optionexchangesymbolTT': 'LO',
#  'optionstart': datetime.datetime(2008, 1, 1, 0, 0),
#  'optionstrikedisplay': 50.0,
#  'optionstrikedisplayTT': 50.0,
#  'optionstrikeincrement': 0.5,
#  'optiontickdisplay': 1.0,
#  'optionticksize': 0.01,
#  'optiontickvalue': 10.0,
#  'pricebandinticks': 25,
#  'productionenabled': 1,
#  'secondaryoptiontickdisplay': 0.0,
#  'secondaryoptionticksize': 0.0,
#  'secondaryoptionticksizerule': 0.0,
#  'secondaryoptiontickvalue': 0.0,
#  'settlementtime': datetime.datetime(1900, 1, 1, 11, 30),
#  'spanfuturecode': 'CL',
#  'spanoptioncode': 'LO',
#  'spanoptionstart': datetime.datetime(2009, 7, 1, 0, 0),
#  'spanoptiontickdisplay': 1.0,
#  'spanoptionticksize': 0.01,
#  'spanstrikedisplay': 50.0,
#  'spantickdisplay': 1.0,
#  'spanticksize': 0.01,
#  'stoptype': 1,
#  'substitutesymbol_eod': 0,
#  'symbol': 'CLE',
#  'tickdisplay': 1.0,
#  'ticksize': 0.01,
#  'tickvalue': 10.0,
#  'timeshifthours': 0,
#  'usedailycustomdata': 1}

# %%
import json
import pickle
import gzip

instr_name = 'EP'
sym = db.instruments.find({'symbol':instr_name}).next()


with gzip.GzipFile(instr_name+'_instrument.pgz', 'w') as f:
    pickle.dump(sym, f)

# %%
with gzip.GzipFile(instr_name+'_instrument.pgz', 'r') as f:
    chain_data = pickle.load(f)

# %%
sym
# Out:
# {'_id': ObjectId('577a4f7c4b01f47f84ca9c9d'),
#  'admcode': 'ES',
#  'admexchangecode': '16',
#  'admfuturepricefactor': 1.0,
#  'admoptionftpfilestrikedisplay': 5.0,
#  'admoptionpricefactor': 1.0,
#  'commissionpercontract': 2.0,
#  'cqgsymbol': 'EP',
#  'customdayboundarytime': datetime.datetime(1900, 1, 1, 12, 50),
#  'datastart': datetime.datetime(2009, 1, 1, 0, 0),
#  'decisionoffsetminutes': 5,
#  'description': 'S&P Mini',
#  'enabled': 1,
#  'exchangesymbol': 'ES',
#  'exchangesymbolTT': 'ES',
#  'idAssetClass': 4,
#  'idexchange': 2,
#  'idinstrument': 11,
#  'idinstrumentgroup': 5,
#  'instrumentid_eod': 73,
#  'instrumentsymbol_pre_eod': 'EP',
#  'instrumentsymboleod_eod': 'SP',
#  'limittickoffset': 10,
#  'listedspread': 0,
#  'margin': 3850,
#  'modeled': 1,
#  'notes': '',
#  'optionadmstrikedisplay': 5.0,
#  'optiondatamonthscollected': 36,
#  'optionenabled': 2,
#  'optionexchangesymbol': 'ES',
#  'optionexchangesymbolTT': 'ES',
#  'optionstart': datetime.datetime(1900, 1, 1, 0, 0),
#  'optionstrikedisplay': 50.0,
#  'optionstrikedisplayTT': 500.0,
#  'optionstrikeincrement': 5.0,
#  'optiontickdisplay': 25.0,
#  'optionticksize': 0.25,
#  'optiontickvalue': 12.5,
#  'pricebandinticks': 48,
#  'productionenabled': 1,
#  'secondaryoptiontickdisplay': 5.0,
#  'secondaryoptionticksize': 0.05,
#  'secondaryoptionticksizerule': 5.0,
#  'secondaryoptiontickvalue': 2.5,
#  'settlementtime': datetime.datetime(1900, 1, 1, 13, 15),
#  'spanfuturecode': 'ES',
#  'spanoptioncode': 'ES',
#  'spanoptionstart': datetime.datetime(2008, 1, 2, 0, 0),
#  'spanoptiontickdisplay': 25.0,
#  'spanoptionticksize': 0.25,
#  'spanstrikedisplay': 25.0,
#  'spantickdisplay': 10.0,
#  'spanticksize': 0.1,
#  'stoptype': 1,
#  'substitutesymbol_eod': 1,
#  'symbol': 'EP',
#  'tickdisplay': 25.0,
#  'ticksize': 0.25,
#  'tickvalue': 12.5,
#  'timeshifthours': 0,
#  'usedailycustomdata': 1}

# %%
import json
import pickle
import gzip

fut_chains = []
for contract in db.contracts.find({
        'idinstrument': sym['idinstrument'], 
        'expirationdate': {'$gt': datetime(2014, 1, 1, 0,0,0)}}).sort('expirationdate').limit(12):    
    fut_chains.append(contract)


with gzip.GzipFile(instr_name+'_futures.pgz', 'w') as f:
#with open('CL.data', 'bw') as f:
    pickle.dump(fut_chains, f)

# %%
fut_chains
# Out:
# [{'_id': ObjectId('577a4f9e4b01f47f84caad7b'),
#   'contractname': 'F.US.EPH14',
#   'cqgsymbol': 'F.EPH14',
#   'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#   'idcontract': 4736,
#   'idinstrument': 11,
#   'month': 'H',
#   'monthint': 3,
#   'year': 2014},
#  {'_id': ObjectId('577a4f9e4b01f47f84caad7d'),
#   'contractname': 'F.US.EPM14',
#   'cqgsymbol': 'F.EPM14',
#   'expirationdate': datetime.datetime(2014, 6, 20, 0, 0),
#   'idcontract': 4738,
#   'idinstrument': 11,
#   'month': 'M',
#   'monthint': 6,
#   'year': 2014},
#  {'_id': ObjectId('577a4f9e4b01f47f84caad84'),
#   'contractname': 'F.US.EPU14',
#   'cqgsymbol': 'F.EPU14',
#   'expirationdate': datetime.datetime(2014, 9, 19, 0, 0),
#   'idcontract': 4745,
#   'idinstrument': 11,
#   'month': 'U',
#   'monthint': 9,
#   'year': 2014},
#  {'_id': ObjectId('577a4f9e4b01f47f84caada4'),
#   'contractname': 'F.US.EPZ14',
#   'cqgsymbol': 'F.EPZ14',
#   'expirationdate': datetime.datetime(2014, 12, 19, 0, 0),
#   'idcontract': 4777,
#   'idinstrument': 11,
#   'month': 'Z',
#   'monthint': 12,
#   'year': 2014},
#  {'_id': ObjectId('577a4f9e4b01f47f84caadbe'),
#   'contractname': 'F.US.EPH15',
#   'cqgsymbol': 'F.EPH15',
#   'expirationdate': datetime.datetime(2015, 3, 20, 0, 0),
#   'idcontract': 4803,
#   'idinstrument': 11,
#   'month': 'H',
#   'monthint': 3,
#   'year': 2015},
#  {'_id': ObjectId('577a4fa04b01f47f84caae7b'),
#   'contractname': 'F.US.EPM15',
#   'cqgsymbol': 'F.EPM15',
#   'expirationdate': datetime.datetime(2015, 6, 19, 0, 0),
#   'idcontract': 5022,
#   'idinstrument': 11,
#   'month': 'M',
#   'monthint': 6,
#   'year': 2015},
#  {'_id': ObjectId('577a4fa14b01f47f84caaf05'),
#   'contractname': 'F.US.EPU15',
#   'cqgsymbol': 'F.EPU15',
#   'expirationdate': datetime.datetime(2015, 9, 18, 0, 0),
#   'idcontract': 5161,
#   'idinstrument': 11,
#   'month': 'U',
#   'monthint': 9,
#   'year': 2015},
#  {'_id': ObjectId('577a4fa14b01f47f84caaf6b'),
#   'contractname': 'F.US.EPZ15',
#   'cqgsymbol': 'F.EPZ15',
#   'expirationdate': datetime.datetime(2015, 12, 18, 0, 0),
#   'idcontract': 5265,
#   'idinstrument': 11,
#   'month': 'Z',
#   'monthint': 12,
#   'year': 2015},
#  {'_id': ObjectId('577a4fa24b01f47f84cab084'),
#   'contractname': 'F.EPH16',
#   'cqgsymbol': 'F.EPH16',
#   'expirationdate': datetime.datetime(2016, 3, 18, 0, 0),
#   'idcontract': 5546,
#   'idinstrument': 11,
#   'month': 'H',
#   'monthint': 3,
#   'year': 2016},
#  {'_id': ObjectId('577a4fa24b01f47f84cab11d'),
#   'contractname': 'F.EPM16',
#   'cqgsymbol': 'F.EPM16',
#   'expirationdate': datetime.datetime(2016, 6, 17, 0, 0),
#   'idcontract': 5700,
#   'idinstrument': 11,
#   'month': 'M',
#   'monthint': 6,
#   'year': 2016},
#  {'_id': ObjectId('577a4fa34b01f47f84cab218'),
#   'contractname': 'F.EPU16',
#   'cqgsymbol': 'F.EPU16',
#   'expirationdate': datetime.datetime(2016, 9, 16, 0, 0),
#   'idcontract': 5951,
#   'idinstrument': 11,
#   'month': 'U',
#   'monthint': 9,
#   'year': 2016},
#  {'_id': ObjectId('577a4fa34b01f47f84cab23c'),
#   'contractname': 'F.EPZ16',
#   'cqgsymbol': 'F.EPZ16',
#   'expirationdate': datetime.datetime(2016, 12, 16, 0, 0),
#   'idcontract': 6570,
#   'idinstrument': 11,
#   'month': 'Z',
#   'monthint': 12,
#   'year': 2016}]

# %%
[x['expirationdate'] for x in fut_chains]
# Out:
# [datetime.datetime(2014, 3, 21, 0, 0),
#  datetime.datetime(2014, 6, 20, 0, 0),
#  datetime.datetime(2014, 9, 19, 0, 0),
#  datetime.datetime(2014, 12, 19, 0, 0),
#  datetime.datetime(2015, 3, 20, 0, 0),
#  datetime.datetime(2015, 6, 19, 0, 0),
#  datetime.datetime(2015, 9, 18, 0, 0),
#  datetime.datetime(2015, 12, 18, 0, 0),
#  datetime.datetime(2016, 3, 18, 0, 0),
#  datetime.datetime(2016, 6, 17, 0, 0),
#  datetime.datetime(2016, 9, 16, 0, 0),
#  datetime.datetime(2016, 12, 16, 0, 0)]

# %%
fut_ids = []

for f in fut_chains:
    fut_ids.append(f['idcontract'])

# %%
fut_ids
# Out:
# [4736, 4738, 4745, 4777, 4803, 5022, 5161, 5265, 5546, 5700, 5951, 6570]

# %%
import json
import pickle
import gzip

opt_chains = []
for contract in db.options.aggregate([
    {'$match': {'idcontract': 4736}},
    {'$sort': { 'strikeprice': 1} },    
    {'$group': {
        '_id': {'date': '$expirationdate'},
        'chain': {'$push': '$$ROOT'},
        }
    },    
    {'$sort':{"_id.date":1}}   
    ]):
    opt_chains.append(contract)

with gzip.GzipFile(instr_name+'_options.pgz', 'w') as f:
#with open('CL.data', 'bw') as f:
    pickle.dump(opt_chains, f)

# %%
opt_chains
# Out:
# [{'_id': {'date': datetime.datetime(2014, 1, 17, 0, 0)},
#   'chain': [{'_id': ObjectId('577a56464b01f47f84cfbbc9'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF145500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488724,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF145500',
#     'optionyear': 2014,
#     'strikeprice': 550.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc6b'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF145500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488886,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF145500',
#     'optionyear': 2014,
#     'strikeprice': 550.0},
#    {'_id': ObjectId('577a56464b01f47f84cfbbca'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF145750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488725,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF145750',
#     'optionyear': 2014,
#     'strikeprice': 575.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc6c'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF145750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488887,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF145750',
#     'optionyear': 2014,
#     'strikeprice': 575.0},
#    {'_id': ObjectId('577a56464b01f47f84cfbbcb'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF146000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488726,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF146000',
#     'optionyear': 2014,
#     'strikeprice': 600.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc6d'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF146000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488888,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF146000',
#     'optionyear': 2014,
#     'strikeprice': 600.0},
#    {'_id': ObjectId('577a56464b01f47f84cfbbcc'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF146250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488727,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF146250',
#     'optionyear': 2014,
#     'strikeprice': 625.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc6e'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF146250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488889,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF146250',
#     'optionyear': 2014,
#     'strikeprice': 625.0},
#    {'_id': ObjectId('577a56464b01f47f84cfbbcd'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF146500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488728,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF146500',
#     'optionyear': 2014,
#     'strikeprice': 650.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc6f'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF146500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488890,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF146500',
#     'optionyear': 2014,
#     'strikeprice': 650.0},
#    {'_id': ObjectId('577a56464b01f47f84cfbbce'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF146750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488729,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF146750',
#     'optionyear': 2014,
#     'strikeprice': 675.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc70'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF146750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488891,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF146750',
#     'optionyear': 2014,
#     'strikeprice': 675.0},
#    {'_id': ObjectId('577a56464b01f47f84cfbbcf'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF147000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488730,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF147000',
#     'optionyear': 2014,
#     'strikeprice': 700.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc71'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF147000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488892,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF147000',
#     'optionyear': 2014,
#     'strikeprice': 700.0},
#    {'_id': ObjectId('577a56464b01f47f84cfbbd0'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF147250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488731,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF147250',
#     'optionyear': 2014,
#     'strikeprice': 725.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc72'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF147250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488893,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF147250',
#     'optionyear': 2014,
#     'strikeprice': 725.0},
#    {'_id': ObjectId('577a56464b01f47f84cfbbd1'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF147500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488732,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF147500',
#     'optionyear': 2014,
#     'strikeprice': 750.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc73'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF147500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488894,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF147500',
#     'optionyear': 2014,
#     'strikeprice': 750.0},
#    {'_id': ObjectId('577a56464b01f47f84cfbbd2'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF147750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488733,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF147750',
#     'optionyear': 2014,
#     'strikeprice': 775.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc74'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF147750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488895,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF147750',
#     'optionyear': 2014,
#     'strikeprice': 775.0},
#    {'_id': ObjectId('577a56464b01f47f84cfbbd3'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF148000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488734,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF148000',
#     'optionyear': 2014,
#     'strikeprice': 800.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc75'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF148000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488896,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF148000',
#     'optionyear': 2014,
#     'strikeprice': 800.0},
#    {'_id': ObjectId('577a56464b01f47f84cfbbd4'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF148250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488735,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF148250',
#     'optionyear': 2014,
#     'strikeprice': 825.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc76'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF148250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488897,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF148250',
#     'optionyear': 2014,
#     'strikeprice': 825.0},
#    {'_id': ObjectId('577a56464b01f47f84cfbbd5'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF148500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488736,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF148500',
#     'optionyear': 2014,
#     'strikeprice': 850.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc77'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF148500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488898,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF148500',
#     'optionyear': 2014,
#     'strikeprice': 850.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbd6'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF148750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488737,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF148750',
#     'optionyear': 2014,
#     'strikeprice': 875.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc78'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF148750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488899,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF148750',
#     'optionyear': 2014,
#     'strikeprice': 875.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbd7'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF149000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488738,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF149000',
#     'optionyear': 2014,
#     'strikeprice': 900.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc79'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF149000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488900,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF149000',
#     'optionyear': 2014,
#     'strikeprice': 900.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbd8'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF149250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488739,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF149250',
#     'optionyear': 2014,
#     'strikeprice': 925.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc7a'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF149250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488901,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF149250',
#     'optionyear': 2014,
#     'strikeprice': 925.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbd9'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF149500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488740,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF149500',
#     'optionyear': 2014,
#     'strikeprice': 950.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc7b'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF149500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488902,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF149500',
#     'optionyear': 2014,
#     'strikeprice': 950.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbda'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF149600',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488741,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF149600',
#     'optionyear': 2014,
#     'strikeprice': 960.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc7c'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF149600',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488903,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF149600',
#     'optionyear': 2014,
#     'strikeprice': 960.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbdb'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF149700',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488742,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF149700',
#     'optionyear': 2014,
#     'strikeprice': 970.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc7d'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF149700',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488904,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF149700',
#     'optionyear': 2014,
#     'strikeprice': 970.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbdc'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF149750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488743,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF149750',
#     'optionyear': 2014,
#     'strikeprice': 975.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc7e'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF149750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488905,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF149750',
#     'optionyear': 2014,
#     'strikeprice': 975.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbdd'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF149800',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488744,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF149800',
#     'optionyear': 2014,
#     'strikeprice': 980.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc7f'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF149800',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488906,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF149800',
#     'optionyear': 2014,
#     'strikeprice': 980.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbde'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF149900',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488745,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF149900',
#     'optionyear': 2014,
#     'strikeprice': 990.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc80'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF149900',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488907,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF149900',
#     'optionyear': 2014,
#     'strikeprice': 990.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbdf'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1410000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488746,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1410000',
#     'optionyear': 2014,
#     'strikeprice': 1000.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc81'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1410000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488908,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1410000',
#     'optionyear': 2014,
#     'strikeprice': 1000.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbe0'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1410100',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488747,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1410100',
#     'optionyear': 2014,
#     'strikeprice': 1010.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc82'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1410100',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488909,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1410100',
#     'optionyear': 2014,
#     'strikeprice': 1010.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbe1'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1410200',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488748,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1410200',
#     'optionyear': 2014,
#     'strikeprice': 1020.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc83'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1410200',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488910,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1410200',
#     'optionyear': 2014,
#     'strikeprice': 1020.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbe2'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1410250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488749,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1410250',
#     'optionyear': 2014,
#     'strikeprice': 1025.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc84'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1410250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488911,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1410250',
#     'optionyear': 2014,
#     'strikeprice': 1025.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbe3'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1410300',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488750,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1410300',
#     'optionyear': 2014,
#     'strikeprice': 1030.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc85'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1410300',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488912,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1410300',
#     'optionyear': 2014,
#     'strikeprice': 1030.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbe4'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1410400',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488751,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1410400',
#     'optionyear': 2014,
#     'strikeprice': 1040.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc86'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1410400',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488913,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1410400',
#     'optionyear': 2014,
#     'strikeprice': 1040.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbe5'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1410500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488752,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1410500',
#     'optionyear': 2014,
#     'strikeprice': 1050.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc87'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1410500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488914,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1410500',
#     'optionyear': 2014,
#     'strikeprice': 1050.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbe6'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1410600',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488753,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1410600',
#     'optionyear': 2014,
#     'strikeprice': 1060.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc88'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1410600',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488915,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1410600',
#     'optionyear': 2014,
#     'strikeprice': 1060.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbe7'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1410700',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488754,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1410700',
#     'optionyear': 2014,
#     'strikeprice': 1070.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc89'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1410700',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488916,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1410700',
#     'optionyear': 2014,
#     'strikeprice': 1070.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbe8'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1410750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488755,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1410750',
#     'optionyear': 2014,
#     'strikeprice': 1075.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc8a'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1410750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488917,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1410750',
#     'optionyear': 2014,
#     'strikeprice': 1075.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbe9'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1410800',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488756,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1410800',
#     'optionyear': 2014,
#     'strikeprice': 1080.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc8b'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1410800',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488918,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1410800',
#     'optionyear': 2014,
#     'strikeprice': 1080.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbea'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1410900',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488757,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1410900',
#     'optionyear': 2014,
#     'strikeprice': 1090.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc8c'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1410900',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488919,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1410900',
#     'optionyear': 2014,
#     'strikeprice': 1090.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbeb'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1411000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488758,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1411000',
#     'optionyear': 2014,
#     'strikeprice': 1100.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc8d'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1411000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488920,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1411000',
#     'optionyear': 2014,
#     'strikeprice': 1100.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbec'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1411100',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488759,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1411100',
#     'optionyear': 2014,
#     'strikeprice': 1110.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc8e'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1411100',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488921,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1411100',
#     'optionyear': 2014,
#     'strikeprice': 1110.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbed'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1411200',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488760,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1411200',
#     'optionyear': 2014,
#     'strikeprice': 1120.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc8f'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1411200',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488922,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1411200',
#     'optionyear': 2014,
#     'strikeprice': 1120.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbee'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1411250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488761,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1411250',
#     'optionyear': 2014,
#     'strikeprice': 1125.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc90'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1411250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488923,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1411250',
#     'optionyear': 2014,
#     'strikeprice': 1125.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbef'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1411300',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488762,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1411300',
#     'optionyear': 2014,
#     'strikeprice': 1130.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc91'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1411300',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488924,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1411300',
#     'optionyear': 2014,
#     'strikeprice': 1130.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbf0'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1411400',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488763,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1411400',
#     'optionyear': 2014,
#     'strikeprice': 1140.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc92'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1411400',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488925,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1411400',
#     'optionyear': 2014,
#     'strikeprice': 1140.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbf1'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1411500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488764,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1411500',
#     'optionyear': 2014,
#     'strikeprice': 1150.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc93'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1411500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488926,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1411500',
#     'optionyear': 2014,
#     'strikeprice': 1150.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbf2'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1411600',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488765,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1411600',
#     'optionyear': 2014,
#     'strikeprice': 1160.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc94'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1411600',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488927,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1411600',
#     'optionyear': 2014,
#     'strikeprice': 1160.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbf3'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1411700',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488766,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1411700',
#     'optionyear': 2014,
#     'strikeprice': 1170.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc95'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1411700',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488928,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1411700',
#     'optionyear': 2014,
#     'strikeprice': 1170.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbf4'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1411750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488767,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1411750',
#     'optionyear': 2014,
#     'strikeprice': 1175.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc96'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1411750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488929,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1411750',
#     'optionyear': 2014,
#     'strikeprice': 1175.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbf5'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1411800',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488768,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1411800',
#     'optionyear': 2014,
#     'strikeprice': 1180.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc97'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1411800',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488930,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1411800',
#     'optionyear': 2014,
#     'strikeprice': 1180.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbf6'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1411900',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488769,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1411900',
#     'optionyear': 2014,
#     'strikeprice': 1190.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc98'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1411900',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488931,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1411900',
#     'optionyear': 2014,
#     'strikeprice': 1190.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbf7'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1412000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488770,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1412000',
#     'optionyear': 2014,
#     'strikeprice': 1200.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc99'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1412000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488932,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1412000',
#     'optionyear': 2014,
#     'strikeprice': 1200.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbf8'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1412100',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488771,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1412100',
#     'optionyear': 2014,
#     'strikeprice': 1210.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc9a'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1412100',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488933,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1412100',
#     'optionyear': 2014,
#     'strikeprice': 1210.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbf9'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1412200',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488772,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1412200',
#     'optionyear': 2014,
#     'strikeprice': 1220.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc9b'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1412200',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488934,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1412200',
#     'optionyear': 2014,
#     'strikeprice': 1220.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbfa'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1412250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488773,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1412250',
#     'optionyear': 2014,
#     'strikeprice': 1225.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc9c'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1412250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488935,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1412250',
#     'optionyear': 2014,
#     'strikeprice': 1225.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbfb'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1412300',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488774,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1412300',
#     'optionyear': 2014,
#     'strikeprice': 1230.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc9d'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1412300',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488936,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1412300',
#     'optionyear': 2014,
#     'strikeprice': 1230.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbfc'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1412400',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488775,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1412400',
#     'optionyear': 2014,
#     'strikeprice': 1240.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc9e'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1412400',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488937,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1412400',
#     'optionyear': 2014,
#     'strikeprice': 1240.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbfd'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1412500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488776,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1412500',
#     'optionyear': 2014,
#     'strikeprice': 1250.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc9f'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1412500',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488938,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1412500',
#     'optionyear': 2014,
#     'strikeprice': 1250.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbfe'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1412600',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488777,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1412600',
#     'optionyear': 2014,
#     'strikeprice': 1260.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbca0'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1412600',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488939,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1412600',
#     'optionyear': 2014,
#     'strikeprice': 1260.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbbff'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1412700',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488778,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1412700',
#     'optionyear': 2014,
#     'strikeprice': 1270.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbca1'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1412700',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488940,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1412700',
#     'optionyear': 2014,
#     'strikeprice': 1270.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc00'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1412750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488779,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1412750',
#     'optionyear': 2014,
#     'strikeprice': 1275.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbca2'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1412750',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488941,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1412750',
#     'optionyear': 2014,
#     'strikeprice': 1275.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc01'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1412800',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488780,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1412800',
#     'optionyear': 2014,
#     'strikeprice': 1280.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbca3'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1412800',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488942,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1412800',
#     'optionyear': 2014,
#     'strikeprice': 1280.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc02'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1412900',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488781,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1412900',
#     'optionyear': 2014,
#     'strikeprice': 1290.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbca4'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1412900',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488943,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1412900',
#     'optionyear': 2014,
#     'strikeprice': 1290.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc03'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1413000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488782,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1413000',
#     'optionyear': 2014,
#     'strikeprice': 1300.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbca5'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1413000',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488944,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1413000',
#     'optionyear': 2014,
#     'strikeprice': 1300.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc04'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1413100',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488783,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1413100',
#     'optionyear': 2014,
#     'strikeprice': 1310.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbca6'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1413100',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488945,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1413100',
#     'optionyear': 2014,
#     'strikeprice': 1310.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc05'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1413200',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488784,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1413200',
#     'optionyear': 2014,
#     'strikeprice': 1320.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbca7'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1413200',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488946,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1413200',
#     'optionyear': 2014,
#     'strikeprice': 1320.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc06'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1413250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488785,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1413250',
#     'optionyear': 2014,
#     'strikeprice': 1325.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbca8'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1413250',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488947,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1413250',
#     'optionyear': 2014,
#     'strikeprice': 1325.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbc07'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1413300',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488786,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'C.US.EPF1413300',
#     'optionyear': 2014,
#     'strikeprice': 1330.0},
#    {'_id': ObjectId('577a56474b01f47f84cfbca9'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPF1413300',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11488948,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
#     'optionname': 'P.US.EPF1413300',
#     'optionyear': 2014,
#     'strikeprice': 1330.0},
#    {'_id': ObjectId('577a56ec4b01f47f84d07092'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPF1413350',
#     'expirationdate': datetime.datetime(2014, 1, 17, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11535091,
#     'optionmonth': 'F',
#     'optionmonthint': 1,
# ...
#     'optionname': 'P.US.EPH1422500',
#     'optionyear': 2014,
#     'strikeprice': 2250.0},
#    {'_id': ObjectId('577a54b24b01f47f84ce0db9'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1422750',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 8341082,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1422750',
#     'optionyear': 2014,
#     'strikeprice': 2275.0},
#    {'_id': ObjectId('577a54b34b01f47f84ce0e5c'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1422750',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 8341245,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1422750',
#     'optionyear': 2014,
#     'strikeprice': 2275.0},
#    {'_id': ObjectId('577a54b24b01f47f84ce0d72'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1423000',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 8341011,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1423000',
#     'optionyear': 2014,
#     'strikeprice': 2300.0},
#    {'_id': ObjectId('577a54b34b01f47f84ce0e06'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1423000',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 8341159,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1423000',
#     'optionyear': 2014,
#     'strikeprice': 2300.0},
#    {'_id': ObjectId('577a54bf4b01f47f84ce1dd3'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1423250',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 8855412,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1423250',
#     'optionyear': 2014,
#     'strikeprice': 2325.0},
#    {'_id': ObjectId('577a54c04b01f47f84ce1dee'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1423250',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 8855439,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1423250',
#     'optionyear': 2014,
#     'strikeprice': 2325.0},
#    {'_id': ObjectId('577a54de4b01f47f84ce37c6'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1423500',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 9258457,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1423500',
#     'optionyear': 2014,
#     'strikeprice': 2350.0},
#    {'_id': ObjectId('577a54de4b01f47f84ce37ca'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1423500',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 9258461,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1423500',
#     'optionyear': 2014,
#     'strikeprice': 2350.0},
#    {'_id': ObjectId('577a54e34b01f47f84ce3afa'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1423750',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 9401423,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1423750',
#     'optionyear': 2014,
#     'strikeprice': 2375.0},
#    {'_id': ObjectId('577a54e34b01f47f84ce3b04'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1423750',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 9401433,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1423750',
#     'optionyear': 2014,
#     'strikeprice': 2375.0},
#    {'_id': ObjectId('577a54e44b01f47f84ce3b81'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1424000',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 9542038,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1424000',
#     'optionyear': 2014,
#     'strikeprice': 2400.0},
#    {'_id': ObjectId('577a54e44b01f47f84ce3b93'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1424000',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 9542056,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1424000',
#     'optionyear': 2014,
#     'strikeprice': 2400.0},
#    {'_id': ObjectId('577a54e64b01f47f84ce407b'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1424250',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 9684178,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1424250',
#     'optionyear': 2014,
#     'strikeprice': 2425.0},
#    {'_id': ObjectId('577a54e64b01f47f84ce407e'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1424250',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 9684181,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1424250',
#     'optionyear': 2014,
#     'strikeprice': 2425.0},
#    {'_id': ObjectId('577a55064b01f47f84ce6272'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1424500',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 10780303,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1424500',
#     'optionyear': 2014,
#     'strikeprice': 2450.0},
#    {'_id': ObjectId('577a55064b01f47f84ce627c'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1424500',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 10780313,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1424500',
#     'optionyear': 2014,
#     'strikeprice': 2450.0},
#    {'_id': ObjectId('577a552f4b01f47f84ce6e87'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1424750',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11140904,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1424750',
#     'optionyear': 2014,
#     'strikeprice': 2475.0},
#    {'_id': ObjectId('577a552f4b01f47f84ce6e91'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1424750',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11140914,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1424750',
#     'optionyear': 2014,
#     'strikeprice': 2475.0},
#    {'_id': ObjectId('577a566b4b01f47f84cfe6c4'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1425000',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11499727,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1425000',
#     'optionyear': 2014,
#     'strikeprice': 2500.0},
#    {'_id': ObjectId('577a566b4b01f47f84cfe6dc'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1425000',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11499751,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1425000',
#     'optionyear': 2014,
#     'strikeprice': 2500.0},
#    {'_id': ObjectId('577a566e4b01f47f84cfea7b'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1425250',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11500678,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1425250',
#     'optionyear': 2014,
#     'strikeprice': 2525.0},
#    {'_id': ObjectId('577a566e4b01f47f84cfead0'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1425250',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11500763,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1425250',
#     'optionyear': 2014,
#     'strikeprice': 2525.0},
#    {'_id': ObjectId('577a566e4b01f47f84cfea7c'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1425500',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11500679,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1425500',
#     'optionyear': 2014,
#     'strikeprice': 2550.0},
#    {'_id': ObjectId('577a566e4b01f47f84cfead1'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1425500',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11500764,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1425500',
#     'optionyear': 2014,
#     'strikeprice': 2550.0},
#    {'_id': ObjectId('577a56ed4b01f47f84d071bb'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1425750',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11535388,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1425750',
#     'optionyear': 2014,
#     'strikeprice': 2575.0},
#    {'_id': ObjectId('577a56f04b01f47f84d074b7'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1425750',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11536152,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1425750',
#     'optionyear': 2014,
#     'strikeprice': 2575.0},
#    {'_id': ObjectId('577a56ed4b01f47f84d071bc'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1426000',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11535389,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1426000',
#     'optionyear': 2014,
#     'strikeprice': 2600.0},
#    {'_id': ObjectId('577a56f04b01f47f84d074b8'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1426000',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11536153,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1426000',
#     'optionyear': 2014,
#     'strikeprice': 2600.0},
#    {'_id': ObjectId('577a56ed4b01f47f84d071bd'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1426250',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11535390,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1426250',
#     'optionyear': 2014,
#     'strikeprice': 2625.0},
#    {'_id': ObjectId('577a56f04b01f47f84d074b9'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1426250',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11536154,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1426250',
#     'optionyear': 2014,
#     'strikeprice': 2625.0},
#    {'_id': ObjectId('577a56ed4b01f47f84d071be'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1426500',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11535391,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1426500',
#     'optionyear': 2014,
#     'strikeprice': 2650.0},
#    {'_id': ObjectId('577a56f14b01f47f84d074ba'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1426500',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11536155,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1426500',
#     'optionyear': 2014,
#     'strikeprice': 2650.0},
#    {'_id': ObjectId('577a56ed4b01f47f84d071bf'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1426750',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11535392,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1426750',
#     'optionyear': 2014,
#     'strikeprice': 2675.0},
#    {'_id': ObjectId('577a56f14b01f47f84d074bb'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1426750',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11536156,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1426750',
#     'optionyear': 2014,
#     'strikeprice': 2675.0},
#    {'_id': ObjectId('577a56ed4b01f47f84d071c0'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1427000',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11535393,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1427000',
#     'optionyear': 2014,
#     'strikeprice': 2700.0},
#    {'_id': ObjectId('577a56f14b01f47f84d074bc'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1427000',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11536157,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1427000',
#     'optionyear': 2014,
#     'strikeprice': 2700.0},
#    {'_id': ObjectId('577a56ed4b01f47f84d071c1'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1427250',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11535394,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1427250',
#     'optionyear': 2014,
#     'strikeprice': 2725.0},
#    {'_id': ObjectId('577a56f14b01f47f84d074bd'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1427250',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11536158,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1427250',
#     'optionyear': 2014,
#     'strikeprice': 2725.0},
#    {'_id': ObjectId('577a573b4b01f47f84d0c6cc'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1427500',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11557165,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1427500',
#     'optionyear': 2014,
#     'strikeprice': 2750.0},
#    {'_id': ObjectId('577a573b4b01f47f84d0c6d1'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1427500',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11557170,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1427500',
#     'optionyear': 2014,
#     'strikeprice': 2750.0},
#    {'_id': ObjectId('577a573e4b01f47f84d0cbd1'),
#     'callorput': 'C',
#     'cqgsymbol': 'C.US.EPH1427750',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11558450,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'C.US.EPH1427750',
#     'optionyear': 2014,
#     'strikeprice': 2775.0},
#    {'_id': ObjectId('577a573e4b01f47f84d0cbd5'),
#     'callorput': 'P',
#     'cqgsymbol': 'P.US.EPH1427750',
#     'expirationdate': datetime.datetime(2014, 3, 21, 0, 0),
#     'idcontract': 4736,
#     'idinstrument': 11,
#     'idoption': 11558454,
#     'optionmonth': 'H',
#     'optionmonthint': 3,
#     'optionname': 'P.US.EPH1427750',
#     'optionyear': 2014,
#     'strikeprice': 2775.0}]}]

# %%
d = {}

# %%
d['sd']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-cf8fccee40ee> in <module>()
# ----> 1 d['sd']
#
# KeyError: 'sd'

# %%
db.futures_data.find({'datetime': datetime(2014, 1, 6, 10,15, 0), 'idcontract': 4736})

# %%
db.futures_data.create_index([('idcontract', pymongo.ASCENDING),('datetime', pymongo.ASCENDING)])
