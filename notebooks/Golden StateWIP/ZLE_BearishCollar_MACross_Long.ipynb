# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys,os
sys.path.append('..')
sys.path.append('../..')
from backtester import matlab, backtester
from backtester.analysis import *
from backtester.strategy import StrategyBase, OptParam
from backtester.swarms.manager import SwarmManager
from backtester.swarms.ranking import SwarmRanker
from backtester.swarms.rebalancing import SwarmRebalance
from backtester.swarms.filters import SwarmFilter
from backtester.costs import CostsManagerEXOFixed
from backtester.exoinfo import EXOInfo


import pandas as pd
import numpy as np
import scipy

# %%
from strategies.strategy_macross_with_trail import StrategyMACrossTrail

# %% [markdown]
# ## Script settings

# %%
STRATEGY_CONTEXT = {
    'strategy': { 
        'class': StrategyMACrossTrail,
        'exo_name': './exo/strategy_2060248.mat',
        'direction': 1,
        'opt_params': [
                #OptParam(name, default_value, min_value, max_value, step)
                OptParam('Direction', 1, -1, 1, 1),
                OptParam('SlowMAPeriod', 20, 10, 30, 2),
                OptParam('FastMAPeriod', 2, 2, 20, 1),
                OptParam('MedianPeriod', 5, 5, 20, 3)
            ],
    },
    'swarm': {
        'members_count': 5,
        'ranking_function': SwarmRanker.highestreturns_14days,
        'rebalance_time_function': SwarmRebalance.every_friday,    
        
        'global_filter_function': SwarmFilter.volatility_chandelier,
        'global_filter_params': {
            'up_factor': 5.0,
            'down_factor': 5.0,
            'period': 5,
        },
        #'global_filter_function': filter_rolling_mean,
        #'global_filter_params': {
        #    'ma_period': 100,
        #}
    },
    'costs':{
        'manager': CostsManagerEXOFixed,
        'context': {
            'costs_options': 3.0,
            'costs_futures': 3.0,
        }
    }
}

# %% [markdown]
# # Backtest class based strategy

# %%
smgr = SwarmManager(STRATEGY_CONTEXT)
smgr.run_swarm()
smgr.pick()
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/ubertrader/anaconda3/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ubertrader/anaconda3/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/ubertrader/Dropbox/tmqrexo/tmqrv/backtester/strategy.py", line 154, in _calc_swarm_member
#     raise Exception('In bi-direction mode fist opt argument must be Direction: 1 or -1')
# Exception: In bi-direction mode fist opt argument must be Direction: 1 or -1
# """
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-9-35aab11f06d8> in <module>()
#       1 smgr = SwarmManager(STRATEGY_CONTEXT)
# ----> 2 smgr.run_swarm()
#       3 smgr.pick()
#
# /home/ubertrader/Dropbox/tmqrexo/tmqrv/backtester/swarms/manager.py in run_swarm(self)
#      67
#      68         # Run strategy swarm
# ---> 69         self.swarm, self.swarm_stats, self.swarm_inposition = self.strategy.run_swarm_backtest()
#      70         #
#      71         # Average swarm multiplied by members_count
#
# /home/ubertrader/Dropbox/tmqrexo/tmqrv/backtester/strategy.py in run_swarm_backtest(self, filtered_swarm, filtered_swarm_equity)
#     208
#     209         pool = Pool()
# --> 210         pool_results = pool.map(self._calc_swarm_member, opts_list)
#     211
#     212         for pool_res in pool_results:
#
# /home/ubertrader/anaconda3/lib/python3.5/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     258         in a list that is returned.
#     259         '''
# --> 260         return self._map_async(func, iterable, mapstar, chunksize).get()
#     261
#     262     def starmap(self, func, iterable, chunksize=None):
#
# /home/ubertrader/anaconda3/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     606             return self._value
#     607         else:
# --> 608             raise self._value
#     609
#     610     def _set(self, i, obj):
#
# Exception: In bi-direction mode fist opt argument must be Direction: 1 or -1

# %%
figsize(10,10)
smgr.swarm_picked.sum(axis=1).plot(label='Picked swarm equity');
smgr.swarm_avg.plot(label='Average swarm equity');
legend(loc=2);

# %% [markdown]
# ## Exo information

# %%
smgr.strategy.exoinfo.exo_info
# Out:
# {'legs': 3,
#  'margin': 1688,
#  'name': 'BearishCollar',
#  'pcf': array([1, 2, 0], dtype=uint8),
#  'pcfqty': array([-1, -1,  1], dtype=int16),
#  'tickincrement': 0.01,
#  'tickvalue': 6,
#  'underlying': 'ZLE'}

# %%
smgr.strategy.exoinfo.data.exo.plot()

# %% [markdown]
# ### Global filter information

# %%
title(smgr.global_filter_data['name'])
smgr.global_filter_data['values'].plot(label='Global filter')
smgr.swarm_avg.plot(label='Average swarm equity');

# %%
smgr.global_filter.plot.area()

# %% [markdown]
# ## Costs information (per 1-exo unit)

# %%
figsize(10,5)
smgr.strategy.costs.plot()

# %% [markdown]
# ## Margin graphs

# %% [markdown]
# ### EXO Margin (per 1 EXO unit)

# %%
smgr.strategy.exoinfo.margin().plot()

# %% [markdown]
# ### Average swarm margin

# %%
(smgr.swarm_picked_margin).rolling(30).mean().plot()

# %%
smgr.save('./swarms/'+smgr.get_swarm_name()+'.swm')
